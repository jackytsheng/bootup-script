[12,17,20,22,23,27,32],
[4,13,18,25,27,29,34],
[2,7,14,18,24,25,27],
[3,8,10,14,21,23,24],
[1,8,9,22,30,31,32],
[2,3,6,8,17,20,23],
[4,5,12,14,17,25,28],
[10,11,14,25,27,28,32],
[2,7,8,9,10,26,30],
[4,10,17,19,21,23,26],
[7,10,11,12,16,21,25],
[4,7,22,23,26,33,35],
[13,15,16,20,25,28,29],
[3,11,16,17,25,26,32],
[7,8,9,15,17,19,32],
[11,13,16,17,18,19,20],
[8,13,21,28,30,31,33],
[4,10,12,13,20,26,34],
[2,13,15,24,25,32,35],
[1,11,12,14,17,19,28],
[2,5,6,10,12,24,25],
[2,5,7,8,11,14,18],
[5,7,8,11,12,19,25],
[10,14,16,21,23,25,34],
[3,10,14,15,23,30,35],
[10,17,19,21,26,31,35],
[1,5,9,12,17,19,24],
[3,4,12,13,14,21,24],
[1,7,13,23,25,26,27],
[10,12,14,15,16,21,25],
[6,16,18,29,30,33,35],
[1,8,14,17,19,21,26],
[1,6,7,18,22,28,33],
[11,17,19,20,23,25,33],
[3,13,16,19,22,25,30],
[1,7,16,20,26,29,32],
[2,6,18,29,30,33,34],
[6,10,12,13,16,20,30],
[6,15,19,22,27,29,35],
[1,2,17,20,26,27,31],
[2,3,7,17,20,22,23],
[1,2,7,8,11,16,28],
[4,9,11,12,21,29,32],
[4,5,9,16,17,29,33],
[4,8,9,11,14,19,20],
[1,12,15,17,21,28,29],
[3,7,20,21,25,30,31],
[1,7,12,13,26,30,34],
[6,9,11,14,19,23,24],
[2,3,13,14,21,24,35],
[1,2,10,16,24,28,31],
[1,5,6,10,16,19,31],
[2,7,9,15,27,31,32],
[9,10,11,17,19,20,35],
[11,15,16,18,22,26,30],
[1,3,8,11,13,31,32],
[3,4,5,7,11,19,28],
[2,8,9,10,19,23,29],
[1,3,9,13,17,23,32],
[2,13,14,16,18,23,28],
[8,12,17,18,21,23,35],
[5,6,14,15,16,24,32],
[5,7,14,18,23,27,33],
[3,9,19,24,27,30,35],
[3,7,9,16,17,28,32],
[11,14,18,23,26,32,34],
[2,21,26,28,31,32,33],
[1,6,10,15,16,21,26],
[8,12,18,20,24,27,35],
[7,14,17,22,24,28,32],
[1,14,17,22,26,28,33],
[1,5,10,12,17,20,27],
[9,10,21,24,25,30,32],
[7,8,9,18,23,30,32],
[3,4,8,22,23,24,31],
[9,12,16,23,26,29,35],
[6,9,17,25,28,32,34],
[3,6,7,14,18,32,35],
[8,12,15,18,19,24,25],
[2,4,12,18,19,27,34],
[1,3,14,17,19,22,26],
[1,12,14,16,21,27,29],
[1,10,11,12,18,20,27],
[10,17,19,20,26,28,33],
[10,16,23,24,27,28,33],
[1,9,16,17,22,24,31],
[1,3,12,13,21,26,31],
[2,5,7,14,25,29,32],
[1,2,3,11,15,26,35],
[3,9,16,25,26,31,34],
[6,14,15,24,26,32,35],
[1,3,6,16,19,20,24],
[9,14,15,19,24,34,35],
[4,5,9,13,25,32,33]
]
rows.reverse()

# %%
from collections import Counter
from itertools import combinations

def find_frequent_combinations(data, combination_length,top_common=None):
    combinations_list = []

    for row in data:
        combinations_list.extend(list(combinations(row, combination_length)))

    count = Counter(combinations_list)
    most_common = count.most_common(top_common)

    return most_common

# %%
from collections import defaultdict

def find_consecutive_strikes(data):
    cur_strike_map = defaultdict(int)
    strike_set_map=defaultdict(int)
    for i in range(1,len(data)):
        prev_row = data[i-1]
        current_row = data[i]

        for number in prev_row:
            if number in current_row:
                cur_strike_map[number] += 1
            elif number in cur_strike_map:
                strike_set_map[(number,cur_strike_map[number])] += 1
                cur_strike_map.pop(number)
        
    
    for k,v in cur_strike_map.items():
        strike_set_map[(k,v)]+=1
    
    return strike_set_map

# %%
from collections import defaultdict

def find_not_consecutive_strikes(data):
    not_shown_strike_map = defaultdict(int)
    not_shown_strike_set_map = defaultdict(int)
    for row in data:
        for number in range(1,36):
            if number not in row:
                not_shown_strike_map[number] += 1
            elif not_shown_strike_map[number] != 0:
                not_shown_strike_set_map[(number,not_shown_strike_map[number])] += 1
                not_shown_strike_map.pop(number)


    
    
    return not_shown_strike_set_map, not_shown_strike_map

# %%
import matplotlib.pyplot as plt
import math

def plot(data,barcolor="steelblue",big_title=""):
    unique_titles = set(key[0] for key in data.keys())
    num_rows = 5
    num_cols = 7
    num_charts = num_rows * num_cols

    fig, axs = plt.subplots(num_rows, num_cols, figsize=(15, 10))

    chart_count = 0
    fig.suptitle(big_title)
    for title in unique_titles:
        filtered_data = {key[1]: value for key, value in data.items() if key[0] == title}

        x_values = list(filtered_data.keys())
        y_values = list(filtered_data.values())

        row = math.floor(chart_count / num_cols)
        col = chart_count % num_cols

        ax = axs[row, col]
        ax.bar(x_values, y_values,color=barcolor)
        ax.set_title(str(title))
        ax.set_yticks(range(max(y_values) + 1))
        ax.yaxis.set_major_locator(plt.MaxNLocator(integer=True))

        chart_count += 1

    # Remove extra subplots if not used
    for i in range(chart_count, num_charts):
        row = math.floor(i / num_cols)
        col = i % num_cols
        fig.delaxes(axs[row, col])

    plt.tight_layout()
    plt.show()

# %%
print(f"data length: {len(rows)}")
gap_result,not_shown_strike = find_not_consecutive_strikes(rows)

x_values = [k for k in not_shown_strike.keys()]
y_values = [v for v in not_shown_strike.values()]

fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(x_values, y_values,color="red")
ax.set_title('Weeks Since Last Shown')
ax.set_xticks(x_values)
ax.set_xticklabels(x_values, rotation=45)

plt.tight_layout()
plt.show()
# Out:
# data length: 270

# %%
print(f'total gap count in the past for all number: {sum(gap_result.values())}')
plot(gap_result,"orange",'Frequency of Gap (x: gap, y: number of times)')
# Out:
# total gap count in the past for all number: 1499

# %%
x_values = [k for k in not_shown_strike.keys()]
y_values = [gap_result[(k,v)] for k,v in not_shown_strike.items()]

fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(x_values, y_values,color="purple")
ax.set_title("Frequency for occurrence given how long number's absence")
ax.set_xticks(x_values)
ax.set_xticklabels(x_values, rotation=45)

plt.tight_layout()
plt.show()

# %%
print(f"data length: {len(rows)}")
result = find_consecutive_strikes(rows)
print(f'total strike in the past for all number: {sum(result.values())}')
plot(result,"steelblue","Frequency of strike (x: strike, y: times)")
# Out:
# data length: 270
# total strike in the past for all number: 309

# %%
one_result = find_frequent_combinations(rows, 1)
x_values = [e[0][0] for e in one_result]
y_values = [e[1] for e  in one_result]

fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(x_values, y_values,color="green")
ax.set_title('Frequency for each number')
ax.set_xticks(x_values)
ax.set_xticklabels(x_values)

plt.tight_layout()
plt.show()

# %%
print(f"data length: {len(rows)}")
for i in range(1,8):
    frequent_result = find_frequent_combinations(rows,i)
    print(f"The combination of {i} numbers that appear most frequently is:")
    for each in result :
        most_frequent_combination, count = each
        if count > 1:
            print(f"Combination that appear more than one time: {most_frequent_combination}, Count: {count}")
# Out:
# data length: 270
# The combination of 1 numbers that appear most frequently is:
# Combination that appear more than one time: 1, Count: 2
# Combination that appear more than one time: 3, Count: 2
# Combination that appear more than one time: 6, Count: 2
# Combination that appear more than one time: 16, Count: 2
# Combination that appear more than one time: 20, Count: 2
# Combination that appear more than one time: 26, Count: 3
# Combination that appear more than one time: 32, Count: 2
# Combination that appear more than one time: 9, Count: 2
# Combination that appear more than one time: 25, Count: 3
# Combination that appear more than one time: 31, Count: 4
# Combination that appear more than one time: 34, Count: 2
# Combination that appear more than one time: 2, Count: 5
# Combination that appear more than one time: 12, Count: 5
# Combination that appear more than one time: 18, Count: 5
# Combination that appear more than one time: 19, Count: 2
# ...

# %%
# combination must appear at least how many time for it to be recommended
threshold = 3 
subset_map = defaultdict(int)
# prepare set array
for i in range(2,8):
    combo_result = find_frequent_combinations(rows,i)
    for e in combo_result:
        subset_map[e[0]] = e[1]

# %%
current_pick = {25,17,19,21,10,7}
print("Choosing the last digit")
y = []
for pick in range(1,36):
    new_pick= current_pick.copy()
    new_pick.add(pick)
    total = 0
    for each_group,value in subset_map.items():
        if set(each_group).issubset(new_pick):
            total += value
    y.append(total)

x_values = [e for e in range(1,36)]

fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(x_values, y,color="pink")
ax.set_title('Recommendation for the last digit given the combination')
ax.set_xticks(x_values)
ax.set_xticklabels(x_values)

plt.tight_layout()
plt.show()
# Out:
# Choosing the last digit

# %%
print("Also consider the spread of number, you want number to be spread")
# Out:
# Also consider the spread of number, you want number to be spread
